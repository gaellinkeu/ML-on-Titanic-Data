# %% [markdown]
# ## Linear Regression on Titanic Dataset
# #
# #### We try to predict with linear if the passenger of the Titanic boat will survive or not

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
df = pd.read_csv('../train.csv', header=0)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# #### Prétraitement

# %%
new_df = df.drop(['PassengerId','Name','Ticket','Cabin'], axis=1)
new_df['Age'].fillna(int(df['Age'].mean()), inplace=True)
new_df['Sex'] = new_df['Sex'].apply(lambda x : ['male', 'female'].index(x))
new_df[['Embarked_C', 'Embarked_Q', 'Embarked_S']] = pd.get_dummies(new_df['Embarked'], dtype=int)
new_df = new_df.drop(['Embarked'], axis=1)
new_df
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked_C  \
# 0           0       3    0  22.0      1      0   7.2500           0
# 1           1       1    1  38.0      1      0  71.2833           1
# 2           1       3    1  26.0      0      0   7.9250           0
# 3           1       1    1  35.0      1      0  53.1000           0
# 4           0       3    0  35.0      0      0   8.0500           0
# ..        ...     ...  ...   ...    ...    ...      ...         ...
# 886         0       2    0  27.0      0      0  13.0000           0
# 887         1       1    1  19.0      0      0  30.0000           0
# 888         0       3    1  29.0      1      2  23.4500           0
# 889         1       1    0  26.0      0      0  30.0000           1
# 890         0       3    0  32.0      0      0   7.7500           0
#
#      Embarked_Q  Embarked_S
# 0             0           1
# 1             0           0
# 2             0           1
# 3             0           1
# 4             0           1
# ..          ...         ...
# 886           0           1
# 887           0           1
# 888           0           1
# 889           0           0
# 890           1           0
#
# [891 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(new_df.loc[:,new_df.columns!='Survived'], new_df['Survived'], test_size=0.8)

# %%
# We get a brief summary of the data
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
import numpy as np
y = [0,1,0,0,0,0,1,0,5]
np.bincount(y)
# Out:
# array([6, 2, 0, 0, 0, 1], dtype=int64)

# %%
y_pred = clf.predict(X_test)

# %%
print('Accuracy:',metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7601683029453016

# %%
from sklearn.tree import export_graphviz
from six import StringIO
from IPython.display import Image
import pydotplus

dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,
                filled=True, rounded=True,
                special_characters=True,feature_names = X_train.columns)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_png('Titacnic_decision_tree.png')
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# Cell In[11], line 11
#       7 export_graphviz(clf, out_file=dot_data,
#       8                 filled=True, rounded=True,
#       9                 special_characters=True,feature_names = X_train.columns)
#      10 graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
# ---> 11 graph.write_png('Titacnic_decision_tree.png')
#      12 Image(graph.create_png())
#
# File c:\Users\Gael\AppData\Local\Programs\Python\Python311\Lib\site-packages\pydotplus\graphviz.py:1810, in Dot.__init__.<locals>.<lambda>(path, f, prog)
#    1800     f.__doc__ = (
#    1801         '''Refer to the docstring accompanying the'''
#    1802         ''''create' method for more information.'''
#    1803     )
#    1805 for frmt in self.formats + ['raw']:
#    1806     self.__setattr__(
#    1807         'write_' + frmt,
#    1808         lambda path,
#    1809         f=frmt,
# -> 1810         prog=self.prog: self.write(path, format=f, prog=prog)
#    1811     )
#    1813     f = self.__dict__['write_' + frmt]
#    1814     f.__doc__ = (
#    1815         '''Refer to the docstring accompanying the'''
#    1816         ''''write' method for more information.'''
#    1817     )
#
# File c:\Users\Gael\AppData\Local\Programs\Python\Python311\Lib\site-packages\pydotplus\graphviz.py:1918, in Dot.write(self, path, prog, format)
#    1915         fobj.write(data)
#    1917     else:
# -> 1918         fobj.write(self.create(prog, format))
#    1919 finally:
#    1920     if close:
#
# File c:\Users\Gael\AppData\Local\Programs\Python\Python311\Lib\site-packages\pydotplus\graphviz.py:1959, in Dot.create(self, prog, format)
#    1957     self.progs = find_graphviz()
#    1958     if self.progs is None:
# -> 1959         raise InvocationException(
#    1960             'GraphViz\'s executables not found')
#    1962 if prog not in self.progs:
#    1963     raise InvocationException(
#    1964         'GraphViz\'s executable "%s" not found' % prog)
#
# InvocationException: GraphViz's executables not found
